# %% [markdown]
# #### LENDING CLUB LOAN (DEFUALT)

# %%
#THIS PROJECT OF A LENDING CLUB LOAN IS BASE ON THE BANK POLICY THAT WE HAVE TO UNDERSTAND .
#THAT WE HAVE ANALYSIS AND WE WILL MAKE THE DATA SO CLEAN THAT THE LENDING CLUB , GET TO KNOW EASILY ABOUT THEIR CUSTOMER BEHAVIOUR.
#POINT THAT WE HAVE TO COVER :
#1.WE WILL SEE THE DATA FIRST.
#2.WE WILL CHECK IT AND WILL ANALYSIS THE SITUATION AROUND THE DATA.
#3.WILL CHECK THE DUPLICATE , NULL VALUE , REMOVE THE UN-USABLE COLUMN AND ROWS OF THE DATA AND MANY MORE ANALYSIS.
#4.THEN WE WILL DROP,MAKE A FUNCTION , AND WILL MAKE A GRAPH FOR BETTER UNDERSANDING MANY MORE ABOUT THE DATA..
# LET GET STARTED.

# %% [markdown]
# We are going to do :
# 1. Data Understanding  (will see the total column rows, tail head,value,dtype and more.)
# 2. Data Cleaning       (will remove un-usable comlunms rows , data,values,dtype, and many more.)
# 3. Data Analysis       (will make graph like , plot , histogram , bar, barh ,and many more analysis.)
# 4. Recommendation      (we will tell about the full analysis of the lending club of loan (default.)

# %%
#IMPORT THE LIBARIES :
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
loan = pd.read_csv("loan_csv.csv")
loan
# Out:
# C:\Users\fv4\AppData\Local\Temp\ipykernel_32952\3071070936.py:1: DtypeWarning: Columns (47) have mixed types. Specify dtype option on import or set low_memory=False.
#   loan = pd.read_csv("loan_csv.csv")
#             id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0      1077501    1296599       5000         5000           4975.0  36 months
# 1      1077430    1314167       2500         2500           2500.0  60 months
# 2      1077175    1313524       2400         2400           2400.0  36 months
# 3      1076863    1277178      10000        10000          10000.0  36 months
# 4      1075358    1311748       3000         3000           3000.0  60 months
# ...        ...        ...        ...          ...              ...        ...
# 39712    92187      92174       2500         2500           1075.0  36 months
# 39713    90665      90607       8500         8500            875.0  36 months
# ...

# %%
#let see the data from diffrent - diffrent angle./

# %% [markdown]
# ## Data understanding.

# %% [markdown]
#  1.Let check the first 10 data.

# %%
loan.head(10)
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 0  1077501    1296599       5000         5000           4975.0  36 months
# 1  1077430    1314167       2500         2500           2500.0  60 months
# 2  1077175    1313524       2400         2400           2400.0  36 months
# 3  1076863    1277178      10000        10000          10000.0  36 months
# 4  1075358    1311748       3000         3000           3000.0  60 months
# 5  1075269    1311441       5000         5000           5000.0  36 months
# 6  1069639    1304742       7000         7000           7000.0  60 months
# 7  1072053    1288686       3000         3000           3000.0  36 months
# 8  1071795    1306957       5600         5600           5600.0  60 months
# 9  1071570    1306721       5375         5375           5350.0  60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# ...

# %% [markdown]
# 2. Let check the last 10 data.

# %%
loan.tail(10)
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv       term  \
# 39707  92666      92661       5000         5000            525.0  36 months
# 39708  92552      92542       5000         5000            375.0  36 months
# 39709  92533      92529       5000         5000            675.0  36 months
# 39710  92507      92502       5000         5000            250.0  36 months
# 39711  92402      92390       5000         5000            700.0  36 months
# 39712  92187      92174       2500         2500           1075.0  36 months
# 39713  90665      90607       8500         8500            875.0  36 months
# 39714  90395      90390       5000         5000           1325.0  36 months
# 39715  90376      89243       5000         5000            650.0  36 months
# 39716  87023      86999       7500         7500            800.0  36 months
#
#       int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# ...

# %% [markdown]
# 3.Let check the total column and rows of the data.

# %%
loan.shape
# Out:
# (39717, 111)

# %% [markdown]
# 4. Let check the data dtype , values , and more things.

# %%
loan.info(verbose = True , show_counts = True )
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 111 columns):
#  #    Column                          Non-Null Count  Dtype
# ---   ------                          --------------  -----
#  0    id                              39717 non-null  int64
#  1    member_id                       39717 non-null  int64
#  2    loan_amnt                       39717 non-null  int64
#  3    funded_amnt                     39717 non-null  int64
#  4    funded_amnt_inv                 39717 non-null  float64
#  5    term                            39717 non-null  object
#  6    int_rate                        39717 non-null  object
#  7    installment                     39717 non-null  float64
#  8    grade                           39717 non-null  object
#  9    sub_grade                       39717 non-null  object
#  10   emp_title                       37258 non-null  object
#  11   emp_length                      38642 non-null  object
# ...

# %% [markdown]
# 5 . Let describe the data.

# %%
loan.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %% [markdown]
# 6. Let see the column name of the data.

# %%
loan.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %% [markdown]
# 7. Let check the null value of the data.

# %%
loan.isnull()
# Out:
#           id  member_id  loan_amnt  funded_amnt  funded_amnt_inv   term  \
# 0      False      False      False        False            False  False
# 1      False      False      False        False            False  False
# 2      False      False      False        False            False  False
# 3      False      False      False        False            False  False
# 4      False      False      False        False            False  False
# ...      ...        ...        ...          ...              ...    ...
# 39712  False      False      False        False            False  False
# 39713  False      False      False        False            False  False
# 39714  False      False      False        False            False  False
# 39715  False      False      False        False            False  False
# 39716  False      False      False        False            False  False
#
#        int_rate  installment  grade  sub_grade  ...  num_tl_90g_dpd_24m  \
# ...

# %%
loan.isnull().count()
# Out:
# id                            39717
# member_id                     39717
# loan_amnt                     39717
# funded_amnt                   39717
# funded_amnt_inv               39717
#                               ...
# tax_liens                     39717
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %% [markdown]
# 8. Let see the duplicate value of the data.

# %%
loan.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 39712    False
# 39713    False
# 39714    False
# 39715    False
# 39716    False
# Length: 39717, dtype: bool

# %%
loan.duplicated().count()
# Out:
# 39717

# %% [markdown]
# ##### After analysis we see that thier are some column which are more important for this loan / lending club data is :
# ##### 1.loan_amount
# ##### 2.term
# ##### 3.interest rate
# ##### 4.grade
# ##### 5.sub grade
# ##### 6.annual income
# ##### 7.purpose of the loan etc
#
#
# ##### The target variable, which we want to compare across the independent variables, is loan status.

# %% [markdown]
# ## Data Cleaning

# %%
#using isnull , sum , keyword to see the null value in the data.
loan.isnull().sum().reset_index()
# Out:
#                           index      0
# 0                            id      0
# 1                     member_id      0
# 2                     loan_amnt      0
# 3                   funded_amnt      0
# 4               funded_amnt_inv      0
# ..                          ...    ...
# 106                   tax_liens     39
# 107             tot_hi_cred_lim  39717
# 108           total_bal_ex_mort  39717
# 109              total_bc_limit  39717
# 110  total_il_high_credit_limit  39717
#
# [111 rows x 2 columns]

# %%
#let understand in percentage way/.
round(loan.isnull().sum()/len(loan.index),2)*100
# Out:
# id                              0.0
# member_id                       0.0
# loan_amnt                       0.0
# funded_amnt                     0.0
# funded_amnt_inv                 0.0
#                               ...
# tax_liens                       0.0
# tot_hi_cred_lim               100.0
# total_bal_ex_mort             100.0
# total_bc_limit                100.0
# total_il_high_credit_limit    100.0
# Length: 111, dtype: float64

# %%
# let remove the unfill data .

# %%
# Removing the missing column with more than 90% data missing.
unfill = loan.columns[100*(loan.isnull().sum()/len(loan.index))> 90]
print(unfill)
# Out:
# Index(['mths_since_last_record', 'next_pymnt_d', 'mths_since_last_major_derog',
#        'annual_inc_joint', 'dti_joint', 'verification_status_joint',
#        'tot_coll_amt', 'tot_cur_bal', 'open_acc_6m', 'open_il_6m',
#        'open_il_12m', 'open_il_24m', 'mths_since_rcnt_il', 'total_bal_il',
#        'il_util', 'open_rv_12m', 'open_rv_24m', 'max_bal_bc', 'all_util',
#        'total_rev_hi_lim', 'inq_fi', 'total_cu_tl', 'inq_last_12m',
#        'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util',
#        'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op',
#        'mo_sin_rcnt_tl', 'mort_acc', 'mths_since_recent_bc',
#        'mths_since_recent_bc_dlq', 'mths_since_recent_inq',
#        'mths_since_recent_revol_delinq', 'num_accts_ever_120_pd',
#        'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl',
#        'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0',
# ...

# %%
#let drop the missing data columns.
loan = loan.drop(unfill, axis = 1)
print(loan.shape)
# Out:
# (39717, 55)

# %%
#let summarize the missing data again.
100*(loan.isnull().sum()/len(loan.index))
# Out:
# id                             0.000000
# member_id                      0.000000
# loan_amnt                      0.000000
# funded_amnt                    0.000000
# funded_amnt_inv                0.000000
# term                           0.000000
# int_rate                       0.000000
# installment                    0.000000
# grade                          0.000000
# sub_grade                      0.000000
# emp_title                      6.191303
# emp_length                     2.706650
# home_ownership                 0.000000
# annual_inc                     0.000000
# verification_status            0.000000
# issue_d                        0.000000
# loan_status                    0.000000
# pymnt_plan                     0.000000
# url                            0.000000
# desc                          33.114284
# purpose                        0.000000
# title                          0.027696
# zip_code                       0.000000
# ...

# %%
# There are now 2 columns having approx 32 and 64% missing values -.
# let's have a look at a few entries in the columns
loan.loc[:, ['desc', 'mths_since_last_delinq']].head()
# Out:
#                                                 desc  mths_since_last_delinq
# 0  Borrower added on 12/22/11 > I need to upgrade...                     NaN
# 1  Borrower added on 12/22/11 > I plan to use thi...                     NaN
# 2                                                NaN                     NaN
# 3    Borrower added on 12/21/11 > to pay for prop...                    35.0
# 4    Borrower added on 12/21/11 > I plan on combi...                    38.0

# %%
#let drop this 2 column too , this is a un-usable columns in the data.

# %%
loan = loan.drop(['desc', 'mths_since_last_delinq'],axis = 1)

# %%
loan.shape
# Out:
# (39717, 53)

# %%
# summarise missing values again.
100*(loan.isnull().sum()/len(loan.index))
# Out:
# id                            0.000000
# member_id                     0.000000
# loan_amnt                     0.000000
# funded_amnt                   0.000000
# funded_amnt_inv               0.000000
# term                          0.000000
# int_rate                      0.000000
# installment                   0.000000
# grade                         0.000000
# sub_grade                     0.000000
# emp_title                     6.191303
# emp_length                    2.706650
# home_ownership                0.000000
# annual_inc                    0.000000
# verification_status           0.000000
# issue_d                       0.000000
# loan_status                   0.000000
# pymnt_plan                    0.000000
# url                           0.000000
# purpose                       0.000000
# title                         0.027696
# zip_code                      0.000000
# addr_state                    0.000000
# dti                           0.000000
# ...

# %% [markdown]
# Here are some more columns with missing values, but let's ignore them for now
#
#
# But let's check whether some rows have a large number of missing values.

# %%
# missing value of rows.
loan.isnull().sum(axis = 1)
# Out:
# 0        1
# 1        0
# 2        1
# 3        0
# 4        0
#         ..
# 39712    4
# 39713    4
# 39714    5
# 39715    5
# 39716    4
# Length: 39717, dtype: int64

# %%
# checking whether some rows have more than 5 missing values.
len(loan[loan.isnull().sum(axis=1) > 5].index)
# Out:
# 0

# %% [markdown]
# The data looks clean. Let's also check whether all columns are in the correct format.

# %%
# checking the detail again
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   member_id                   39717 non-null  int64
#  2   loan_amnt                   39717 non-null  int64
#  3   funded_amnt                 39717 non-null  int64
#  4   funded_amnt_inv             39717 non-null  float64
#  5   term                        39717 non-null  object
#  6   int_rate                    39717 non-null  object
#  7   installment                 39717 non-null  float64
#  8   grade                       39717 non-null  object
#  9   sub_grade                   39717 non-null  object
#  10  emp_title                   37258 non-null  object
#  11  emp_length                  38642 non-null  object
#  12  home_ownership              39717 non-null  object
# ...

# %%
# The column int_rate is character type, let's convert it to float.
loan['int_rate'] = loan['int_rate'].apply(lambda x: pd.to_numeric(x.split("%")[0]))

# %%
#checking the columns
loan['int_rate']
# Out:
# 0        10.65
# 1        15.27
# 2        15.96
# 3        13.49
# 4        12.69
#          ...
# 39712     8.07
# 39713    10.28
# 39714     8.07
# 39715     7.43
# 39716    13.75
# Name: int_rate, Length: 39717, dtype: float64

# %%
#checking column.
loan['emp_length'].reset_index()
# Out:
#        index emp_length
# 0          0  10+ years
# 1          1   < 1 year
# 2          2  10+ years
# 3          3  10+ years
# 4          4     1 year
# ...      ...        ...
# 39712  39712    4 years
# 39713  39713    3 years
# 39714  39714   < 1 year
# 39715  39715   < 1 year
# 39716  39716   < 1 year
#
# [39717 rows x 2 columns]

# %%
# also, lets extract the numeric part from the variable employment length
# first, let's drop the missing values
loan = loan[~loan['emp_length'].isnull()]

# using regular expression to extract numeric values from the string
import re #(regular expressions short name in jypter)

loan['emp_length'] = loan['emp_length'].apply(lambda x:re.findall('\d+',str(x))[0])

# convert to numeric
loan['emp_length'] = loan['emp_length'].apply(lambda x :pd.to_numeric (x))
# Out:
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# <>:8: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\fv4\AppData\Local\Temp\ipykernel_32952\3326257049.py:8: SyntaxWarning: invalid escape sequence '\d'
#   loan['emp_length'] = loan['emp_length'].apply(lambda x:re.findall('\d+',str(x))[0])

# %%
# value counting of the emp_length column.
loan['emp_length'].value_counts()
# Out:
# emp_length
# 10    8879
# 1     7823
# 2     4388
# 3     4095
# 4     3436
# 5     3282
# 6     2229
# 7     1773
# 8     1479
# 9     1258
# Name: count, dtype: int64

# %%
# looking at type of the columns again.
loan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38642 entries, 0 to 39716
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          38642 non-null  int64
#  1   member_id                   38642 non-null  int64
#  2   loan_amnt                   38642 non-null  int64
#  3   funded_amnt                 38642 non-null  int64
#  4   funded_amnt_inv             38642 non-null  float64
#  5   term                        38642 non-null  object
#  6   int_rate                    38642 non-null  float64
#  7   installment                 38642 non-null  float64
#  8   grade                       38642 non-null  object
#  9   sub_grade                   38642 non-null  object
#  10  emp_title                   37202 non-null  object
#  11  emp_length                  38642 non-null  int64
#  12  home_ownership              38642 non-null  object
# ...

# %% [markdown]
# ## Data Analysis
#
# Let's now move to data analysis. To start with, let's understand the objective of the analysis clearly and identify the variables that we want to consider for analysis.

# %%
behaviour_var =  [
  "delinq_2yrs",
  "earliest_cr_line",
  "inq_last_6mths",
  "open_acc",
  "pub_rec",
  "revol_bal",
  "revol_util",
  "total_acc",
  "out_prncp",
  "out_prncp_inv",
  "total_pymnt",
  "total_pymnt_inv",
  "total_rec_prncp",
  "total_rec_int",
  "total_rec_late_fee",
  "recoveries",
  "collection_recovery_fee",
  "last_pymnt_d",
  "last_pymnt_amnt",
  "last_credit_pull_d",
  "application_type"]
behaviour_var
# Out:
# ['delinq_2yrs',
#  'earliest_cr_line',
#  'inq_last_6mths',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'last_credit_pull_d',
#  'application_type']

# %%
# let's now remove the behaviour variables from analysis
df = loan.drop(behaviour_var, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 38642 entries, 0 to 39716
# Data columns (total 32 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          38642 non-null  int64
#  1   member_id                   38642 non-null  int64
#  2   loan_amnt                   38642 non-null  int64
#  3   funded_amnt                 38642 non-null  int64
#  4   funded_amnt_inv             38642 non-null  float64
#  5   term                        38642 non-null  object
#  6   int_rate                    38642 non-null  float64
#  7   installment                 38642 non-null  float64
#  8   grade                       38642 non-null  object
#  9   sub_grade                   38642 non-null  object
#  10  emp_title                   37202 non-null  object
#  11  emp_length                  38642 non-null  int64
#  12  home_ownership              38642 non-null  object
# ...

# %%
# also, we will not be able to use the variables zip code, address, state etc.
# the variable 'title' is derived from the variable 'purpose'
# thus let get rid of all these variables as well

df = df.drop(['title', 'url', 'zip_code', 'addr_state'], axis=1)

# %% [markdown]
# Next, let's have a look at the target variable - loan_status.

# %%
# let name of the fully  paid (0) and charged off (1).
df['loan_status'] = df['loan_status'].astype('category')
df['loan_status'].value_counts()
# Out:
# loan_status
# Fully Paid     32145
# Charged Off     5399
# Current         1098
# Name: count, dtype: int64

# %%
# filtering only fully paid or charged-off
df = df[df['loan_status'] != 'Current']
df['loan_status'] = df['loan_status'].apply(lambda x: 0 if x=='Fully Paid' else 1)

# converting loan_status to integer type
df['loan_status'] = df['loan_status'].apply(lambda x: pd.to_numeric(x))

# summarising the values
df['loan_status'].value_counts()
# Out:
# loan_status
# 0    32145
# 1     5399
# Name: count, dtype: int64

# %% [markdown]
# ## Univariate Analaysis

# %%
# default rate
round(np.mean(df['loan_status']), 5)*100
# Out:
# 14.38

# %% [markdown]
# THE OVERALL DEFUALT RATE IS 14.38%.

# %%
# plotting default rates across grade of the loan
sns.barplot(x='grade', y='loan_status', data=df , color = 'green' )
plt.title("Compare between loan_status and grade ")
plt.show()

# %%
# lets define a function to plot loan_status across categorical variables
def plot_cat(cat_var):
    sns.barplot(x=cat_var, y='loan_status', data=df ,color = 'red')    
    plt.show()

# %%
# compare default rates across grade of loan
plt.title("Compare between loan_status and grade")
plot_cat('grade')

# %% [markdown]
# Clearly, as the grade of loan goes from A to G, the default rate increases.

# %%
# term: 60 months loans default more than 36 months loans
plt.title("Compare between loan_status and term")
plot_cat('term')

# %%
# sub-grade: as expected - A1 is better than A2 better than A3 and so on 
plt.figure(figsize=(16, 6))
plt.title("Compare Between loan_status and sub_grade")
plt.grid
plot_cat('sub_grade')

# %%
# home ownership: not a great discriminator
plt.title("Compare Between loan_status and home_ownership")
plot_cat('home_ownership')

# %%
# verification_status: surprisingly, verified loans default more than not verifiedb
plt.title("Compare between loan_status and verification_status ")
plot_cat('verification_status')

# %%
# purpose: small business loans defualt the most, then renewable energy and education
plt.figure(figsize=(16, 6))
plt.title("Comapare between loan_status and purpose ")
plot_cat('purpose')

# %%
# first lets convert the year column into datetime and then extract year and month from it
df['issue_d'].head()
# Out:
# 0    Dec-11
# 1    Dec-11
# 2    Dec-11
# 3    Dec-11
# 5    Dec-11
# Name: issue_d, dtype: object

# %%
from datetime import datetime
df['issue_d'] = df['issue_d'].apply(lambda x: datetime.strptime(x, '%b-%y'))

# %%
# extracting month and year from issue_date
df['month'] = df['issue_d'].apply(lambda x: x.month)
df['year'] = df['issue_d'].apply(lambda x: x.year)

# %%
# let's first observe the number of loans granted across years
df.groupby('year').year.count()
# Out:
# year
# 2007      251
# 2008     1562
# 2009     4716
# 2010    11214
# 2011    19801
# Name: year, dtype: int64

# %% [markdown]
# We can see that the number of loans has increased steadily across years.

# %%
# number of loans across months
df.groupby('month').month.count()
# Out:
# month
# 1     2331
# 2     2278
# 3     2632
# 4     2756
# 5     2838
# 6     3094
# 7     3253
# 8     3321
# 9     3394
# 10    3637
# 11    3890
# 12    4120
# Name: month, dtype: int64

# %% [markdown]
# Most loans are granted in December

# %%
# lets compare the default rates across years
# the default rate had suddenly increased in 2011, inspite of reducing from 2008 till 2010
plt.title("Compare between loan_status in year")
plot_cat('year')

# %%
# comparing default rates across months: not much variation across months
plt.figure(figsize=(16, 6))
plt.title("Compare between loan_status in months")
plot_cat('month')

# %% [markdown]
# Let's now analyse how the default rate varies across continuous variables.

# %%
# loan amount: the median loan amount is around 10,000
sns.displot(df['loan_amnt'])
plt.show()

# %% [markdown]
# The easiest way to analyse how default rates vary across continous variables is to bin the variables into discrete categories.

# %%
#Let's bin the loan amount variable into small, medium, high, very high.
def loan_amount(n):
    if n < 5000:
        return 'low'
    elif n >=5000 and n < 15000:
        return 'medium'
    elif n >= 15000 and n < 25000:
        return 'high'
    else:
        return 'very high'
        
df['loan_amnt'] = df['loan_amnt'].apply(lambda x: loan_amount(x))

# %%
df['loan_amnt'].value_counts()
# Out:
# loan_amnt
# medium       20157
# high          7572
# low           7095
# very high     2720
# Name: count, dtype: int64

# %%
# let's compare the default rates across loan amount type
# higher the loan amount, higher the default rate
plt.title("loan_status by medium,high,low,very high")
plot_cat('loan_amnt')

# %%
# let's also convert funded amount invested to bins
df['funded_amnt_inv'] = df['funded_amnt_inv'].apply(lambda x: loan_amount(x))

# %%
# funded amount invested
plt.title("loan_status and funded amunt investment ")
plot_cat('funded_amnt_inv')

# %%
# lets also convert interest rate to low, medium, high
def int_rate(n):
    if n <= 10:
        return 'low'
    elif n > 10 and n <=15:
        return 'medium'
    else:
        return 'high'
    
    
df['int_rate'] = df['int_rate'].apply(lambda x: int_rate(x))

# %%
# comparing default rates across rates of interest
plt.title("Compare between loan_status and int_rate")
plot_cat('int_rate')

# %%
# debt to income ratio
def dti(n):
    if n <= 10:
        return 'low'
    elif n > 10 and n <=20:
        return 'medium'
    else:
        return 'high'
    

df['dti'] = df['dti'].apply(lambda x: dti(x))

# %%
# comparing default rates across debt to income ratio.
plt.title("Compare between loan_status and dti ")
plot_cat('dti')

# %%
# funded amount
def funded_amount(n):
    if n <= 5000:
        return 'low'
    elif n > 5000 and n <=15000:
        return 'medium'
    else:
        return 'high'
    
df['funded_amnt'] = df['funded_amnt'].apply(lambda x: funded_amount(x))

# %%
plt.title("Compare between loan_status and funded-amt")
plot_cat('funded_amnt')

# %%
# installment
def installment(n):
    if n <= 200:
        return 'low'
    elif n > 200 and n <=400:
        return 'medium'
    elif n > 400 and n <=600:
        return 'high'
    else:
        return 'very high'
    
df['installment'] = df['installment'].apply(lambda x: installment(x))

# %%
# comparing default rates across installment
plt.title("Compare between loan_status and installment")
plot_cat('installment')

# %%
# annual income
def annual_income(n):
    if n <= 50000:
        return 'low'
    elif n > 50000 and n <=100000:
        return 'medium'
    elif n > 100000 and n <=150000:
        return 'high'
    else:
        return 'very high'

df['annual_inc'] = df['annual_inc'].apply(lambda x: annual_income(x))

# %%
# annual income and default rate
plt.title("Compare between loan_status and annual_inc")
plot_cat('annual_inc')

# %%
# employment length
# first, let's drop the missing value in emp length
df = df[~df['emp_length'].isnull()]

# binning the variable
def emp_length(n):
    if n <= 1:
        return 'fresher'
    elif n > 1 and n <=3:
        return 'junior'
    elif n > 3 and n <=7:
        return 'senior'
    else:
        return 'expert'

df['emp_length'] = df['emp_length'].apply(lambda x: emp_length(x))

# %%
# emp_length and default rate
plt.title("Compare between loan_status and emp_length")
plot_cat('emp_length')

# %% [markdown]
# ## Segmented Univariate Analysis

# %%
# purpose: small business loans defualt the most, then renewable energy and education
plt.figure(figsize=(16, 6))
plt.title("Comapre loan_status and purpose in segmented univariate analysis")
plot_cat('purpose')

# %% [markdown]
# In the upcoming analyses, we will segment the loan applications across the purpose of the loan, since that is a variable affecting many other variables - the type of applicant, interest rate, income, and finally the default rate.

# %%
# lets first look at the number of loans for each type (purpose) of the loan
plt.figure(figsize=(16, 6))
plt.title("counting of purpose base on the analysis ")
sns.countplot(x='purpose', data=df)
plt.show()

# %% [markdown]
# Let's analyse the top 4 types of loans based on purpose: consolidation, credit card, home improvement and major purchase.

# %%
# filtering the df for the 4 types of loans mentioned above
main_purposes = ["credit_card","debt_consolidation","home_improvement","major_purchase"]
df = df[df['purpose'].isin(main_purposes)]
df['purpose'].value_counts()
# Out:
# purpose
# debt_consolidation    17675
# credit_card            4899
# home_improvement       2785
# major_purchase         2080
# Name: count, dtype: int64

# %%
# plotting number of loans by purpose 
plt.title("count of the top 4 purpose")
sns.countplot(x=df['purpose'])
plt.show()

# %%
# let's now compare the default rates across two types of categorical variables
plt.figure(figsize=[10, 6])
plt.title("purpose top 4 analysis in term wise by loan_status")
sns.barplot(x='term', y="loan_status", hue='purpose', data=df)
plt.show()

# %%
# lets write a function which takes a categorical variable and plots the default rate
def plot_segmented(cat_var):
    plt.figure(figsize=(10, 6))
    sns.barplot(x=cat_var, y='loan_status', hue='purpose', data=df)
    plt.show()

    
plot_segmented('term')

# %%
# grade of loan
plot_segmented('grade')

# %%
# home ownership
plot_segmented('home_ownership')

# %%
#year
plot_segmented('year')

# %%
# emp_length
plot_segmented('emp_length')

# %%
# loan_amnt: same trend across loan purposes
plot_segmented('loan_amnt')

# %%
# interest rate
plot_segmented('int_rate')

# %%
# installment
plot_segmented('installment')

# %%
# debt to income ratio
plot_segmented('dti')

# %%
# annual income
plot_segmented('annual_inc')

# %% [markdown]
# ## Let analysis in more easy way for a landing club

# %%
sizes = [15, 30, 45, 10]  
labels = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term'] 
colors = ['gold', 'yellowgreen', 'lightcoral', 'lightskyblue']
plt.figure(figsize=(8, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Lending Club Loan Status in pie chart')
plt.show()

# %%
sizes = [15, 30]  
labels = ['loan_amnt', 'funded_amnt']
colors = ['gold','lightskyblue']
plt.figure(figsize=(8, 8)) 
plt.pie(sizes, labels=labels, colors=colors, autopct='%1.1f%%', startangle=90)
plt.axis('equal')
plt.title('Comparison of loan_amt and funded_amt')
plt.show()

# %%
data = [44, 45, 40, 41]
labels = ['loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term'] 
colors = sns.color_palette('bright')
plt.title("Comparision between loan_amt and funded_amt,funded_amt_invt and term ")
plt.pie(data, labels=labels, colors=colors, autopct='%.0f%%')
plt.show()

# %%
sns.set(rc={'figure.figsize':(15,10)})
sns.violinplot(x="loan_amnt",y="term",data=df, split=True,palette='inferno')
plt.title(" Comparing loan status by term", fontsize=20)
plt.xlabel("Loan status ", fontsize=15)
plt.ylabel("Term", fontsize=15);
# Out:
# C:\Users\fv4\AppData\Local\Temp\ipykernel_32952\2649796465.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.violinplot(x="loan_amnt",y="term",data=df, split=True,palette='inferno')

# %% [markdown]
# let's see an example using annual_inc as the categorical variable.

# %%
 #variation of default rate across annual_inc
df.groupby('annual_inc').loan_status.mean().sort_values(ascending=False)
# Out:
# annual_inc
# low          0.157966
# medium       0.130075
# very high    0.101570
# high         0.097749
# Name: loan_status, dtype: float64

# %%
# one can write a function which takes in a categorical variable and computed the average 
# default rate across the categories
# It can also compute the 'difference between the highest and the lowest default rate' across the 
# categories, which is a decent metric indicating the effect of the varaible on default rate

def diff_rate(cat_var):
    default_rates = df.groupby(cat_var).loan_status.mean().sort_values(ascending=False)
    return (round(default_rates, 2), round(default_rates[0] - default_rates[-1], 2))

default_rates, diff = diff_rate('annual_inc')
print(default_rates) 
print(diff)
# Out:
# annual_inc
# low          0.16
# medium       0.13
# very high    0.10
# high         0.10
# Name: loan_status, dtype: float64
# 0.06
# C:\Users\fv4\AppData\Local\Temp\ipykernel_32952\2545888794.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return (round(default_rates, 2), round(default_rates[0] - default_rates[-1], 2))

# %% [markdown]
# there is a 6% increase in default rate as you go from high to low annual income

# %%
# filtering all the object type variables
df_categorical = df.loc[:, df.dtypes == object]
df_categorical['loan_status'] = df['loan_status']

# Now, for each variable, we can compute the incremental diff in default rates
print([i for i in df.columns])
# Out:
# ['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv', 'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title', 'emp_length', 'home_ownership', 'annual_inc', 'verification_status', 'issue_d', 'loan_status', 'pymnt_plan', 'purpose', 'dti', 'initial_list_status', 'collections_12_mths_ex_med', 'policy_code', 'acc_now_delinq', 'chargeoff_within_12_mths', 'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens', 'month', 'year']
# C:\Users\fv4\AppData\Local\Temp\ipykernel_32952\2256099650.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_categorical['loan_status'] = df['loan_status']

# %%
# storing the diff of default rates for each column in a dict
d = {key: diff_rate(key)[1]*100 for key in df_categorical.columns if key != 'loan_status'}
print(d)
# Out:
# {'loan_amnt': 7.000000000000001, 'funded_amnt': 5.0, 'funded_amnt_inv': 6.0, 'term': 15.0, 'int_rate': 19.0, 'installment': 3.0, 'grade': 27.0, 'sub_grade': 46.0, 'emp_title': 100.0, 'emp_length': 2.0, 'home_ownership': 16.0, 'annual_inc': 6.0, 'verification_status': 4.0, 'pymnt_plan': 0.0, 'purpose': 5.0, 'dti': 5.0, 'initial_list_status': 0.0}
# C:\Users\fv4\AppData\Local\Temp\ipykernel_32952\2545888794.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   return (round(default_rates, 2), round(default_rates[0] - default_rates[-1], 2))
# ...

# %% [markdown]
# ## Recommendation

# %% [markdown]
# This the lending club loan (default) , is the project where we analysis the loan status about..
#
#
# loan_amnt , funded amount, funded amount investment .
#
#
# checking it by the term , charged off , fully paid, center and more way to analysis the lending club loan status ..
#
#
# and also by the customer behaviour and also check their way to lending club (default).
#
#
# So, lending club , just need to check the loan stataus , by the some of the main things in this analysis that will help you guy see fast and easily get to know about the customer,as easily you guys can.
#
# We have analysis it dept by dept for the lending club loan (defualt) so, they can utalize it and understanding it easily for them .
#
#
#
# feedback:
#  so that it is what it is in the lending club loan . very exciting project it was , get to know so much about the loan system and the bank system of the borrowers and the investor ., that it is what we have analysis in this lending club project ..
